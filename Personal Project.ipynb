# %%
Analysis 1: 
# The relationship between sleep duration and subjective well-being

Study variables:
# SLEEP_avg_sleep_hours (average number of hours of sleep per night)
# Wellbeing_subjective_happiness_scale_happy (happiness number)

Reason for selection:
# The choice was made because sleep has a big effect on both physical and mental health. 
# Looking into the link between sleep length and health can help us figure out 
# if there is a link between rest and mental health.

Analysis method:
# I will use what I learned in hw4 about confidence ranges to do the analysis. 
# Sort the data into groups based on the amount of time spent sleeping, 
# and then figure out the confidence range of the happiness score to see 
# if there is a strong link between sleep time and happiness.

# Sort the data into groups based on sleep time. 
# For example, make a high sleep group for people who sleep more than or equal to 8 hours a night 
# and a low sleep group for people who sleep less than 8 hours a night. 
# We found the average of the subjective well-being scores for each group 
# to get an idea of the usual level of well-being in the groups that slept a lot and a lot. 
# Find the 95% confidence range for the mean happiness for each group. 
# Check to see if there is overlap between the two confidence bands for the high sleep group 
# and the low sleep group. 
# If the two confidence ranges don't touch, 
# it means that the average level of happiness may be very different between groups. 
# If the confidence intervals meet, it means that the amount of sleep may not have a big effect on health.

Possible results and explanations:
# The confidence range for the happiness score was higher in the high sleep time group than 
# in the low sleep time group. This suggests that getting more sleep may make people happier.

# If the confidence intervals overlap, 
# it means that the effect of sleep time on happiness might not be that important. 
# More study might be needed to find other factors that affect happiness.

Project dependencies:
# This study shows how the length of sleep might affect a person's overall health and happiness. 
# A lot of people agree that getting enough sleep is important for mental health. 
# The link between rest and well-being can be found out more 
# by looking at the changes in how happy people are in different sleep time groups. 
# In the event that the results are significant, 
# they could back up programs that stress how important good sleep habits are for health. 
# This link gives us information for future efforts to improve mental health and lifestyle, 
# and it helps programs show how good sleep health is for general health.



Analysis 2: 
# The relationship between exercise time and subjective well-being

Study variables:
# ACTIVITY_avg_exercise_hours (average weekly exercise hours).
# WELLNESS_subjective_happiness_scale_happy (subjective happiness scale)

Reason for selection:
# Exercise has been shown to have a positive effect on mental health. 
# Studying the relationship between exercise time and 
# happiness helps us understand the role of physical activity in improving happiness.

Analysis method:
# Use the hypothesis testing skills you learned in hw5 to figure out 
# if the amount of time spent exercising has a big effect on your overall health.

# Each set of data was split into two groups based on how much exercise each person did. 
# One group had more than 150 minutes of exercise per week, 
# and the other had less than 150 minutes of exercise per week. 
# To see the difference in happiness between the groups that exercised a lot and those that exercised little, 
# find the mean value of happiness for each group. 
# The independent samples t test can be used if the happy data 
# from the two groups follow a normal distribution and have the same range. 
# Use the Mann-Whitney U test, 
# a non-parametric test that works well for samples that are not fairly spread out, 
# if the data are not normally distributed or have unequal variances. 
# Use the chosen test method to find the p-value. Set the level of significance, which is typically 0.05:
# p value < 0.05: 
# The null hypothesis is not true, showing that exercise time has a big effect on happiness.
# p value > 0.05: 
# The null hypothesis can't be thrown out, 
# which means that the effect of exercise time on happiness isn't important.


Possible results and explanations:
# The people in the high exercise time group scored significantly higher on subjective well-being 
# than the people in the low exercise time group. 
# This suggests that exercise time may have a good effect on well-being.

# If there aren't any big differences, 
# it means that the amount of time spent exercising might not have a big impact on health, 
# and more study into other factors might be needed.


Project dependencies:
# Hypothesis testing is used in this study to show how exercise time might affect subjective well-being. 
# Researcher have found over and over again that exercise is good for your mental health. 
# The project's main idea that exercise is good for you can be backed up 
# by the analysis results if they are important. 
# With this information, projects can show how exercise can help people's mental health, 
# give people a scientific reason to be more active, and strengthen the link between having friends, 
# living an active life, and being happy.



Analysis 3:
# The relationship between working hours and subjective well-being

Study varriables:
# WORK_avg_work_hours (average weekly work hours)
# WELLNESS_subjective_happiness_scale_happy (subjective happiness scale)

Reason for selection:
# In psychology, the link between work and happiness has always been a big deal. 
# Figuring out the link between working hours and happiness can help you figure out 
# how much work affects a person's mental health.

Analysis method:
# There was a linear regression model used to look at how working hours affected people's own happiness.

# The happiness score (WELLNESS_subjective_happiness_scale_happy) 
# should be used as the dependent variable and the average weekly working hours 
# should be used as the independent variable. Make a simple model for linear regression. 
# The least squares method was used to find the model parameters. 
# Check the test results to see if the p-value is less than 0.05, 
# which is the amount of significance that is usually used:
# p value < 0.05: The number of hours worked has a big impact on happiness.
# p value > 0.05: There is no significant link between working hours and happiness.

Possible results and explanations:
# People who worked fewer hours had much better well-being scores, 
# which suggests that having less work to do may be good for well-being.

# If there isn't a significant connection, 
# it means that working hours may not have a big impact on well-being and 
# that more study may need to be done on other factors.


Project dependencies:
# Based on this study, working hours may have an effect on people's overall happiness. 
# In today's world, work load has a big effect on people's mental health and happiness with their lives. 
# Use a linear regression model to look into how working hours affect how happy people are. 
# If the results are important, they can be used as evidence to support project 
# talks about how to balance work and mental health. 
# The results show how important it is to find the right mix between work and well-being. 
# They also give useful information for projects that 
# aim to improve people's healthy views of their working hours, 
# which in turn enhances their own well-being.
# Out:
#   Cell In[1], line 1
#     Analysis 1:
#              ^
# SyntaxError: invalid syntax
